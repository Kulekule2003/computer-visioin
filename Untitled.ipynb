# %%
a = ["okure","james","word","enock"]
for i, v in enumerate(a):
    print(i, v)
# Out:
# 0 okure
# 1 james
# 2 word
# 3 enock

# %%
label_map = { label : i for i, label in enumerate(a)}
label_map
# Out:
# {'okure': 0, 'james': 1, 'word': 2, 'enock': 3}
